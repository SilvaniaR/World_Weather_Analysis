# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 759

# %%
#Import dependencies
import requests
from config2 import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | hermiston
# Processing Record 3 of Set 1 | aykhal
# Processing Record 4 of Set 1 | isla vista
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | cabo san lucas
# Processing Record 10 of Set 1 | ternate
# Processing Record 11 of Set 1 | naze
# Processing Record 12 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 1 | quesnel
# Processing Record 14 of Set 1 | altus
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | vinh
# Processing Record 21 of Set 1 | jiayuguan
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | manta
# Processing Record 24 of Set 1 | lompoc
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | bambous virieux
# Processing Record 29 of Set 1 | port alfred
# Processing Record 30 of Set 1 | leningradskiy
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | sur
# Processing Record 34 of Set 1 | kaitangata
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | luanda
# Processing Record 37 of Set 1 | thompson
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | riyadh
# Processing Record 40 of Set 1 | grand gaube
# Processing Record 41 of Set 1 | makat
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | jardim
# Processing Record 44 of Set 1 | saint george
# Processing Record 45 of Set 1 | hualmay
# Processing Record 46 of Set 1 | kisesa
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | alofi
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | north bend
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | pierre
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | tokur
# Processing Record 6 of Set 2 | tasiilaq
# Processing Record 7 of Set 2 | margate
# Processing Record 8 of Set 2 | karasjok
# Processing Record 9 of Set 2 | luba
# Processing Record 10 of Set 2 | udachnyy
# Processing Record 11 of Set 2 | ilhabela
# Processing Record 12 of Set 2 | kushima
# Processing Record 13 of Set 2 | maceio
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | maningrida
# Processing Record 16 of Set 2 | kiunga
# Processing Record 17 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 2 | sembe
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | teya
# Processing Record 22 of Set 2 | sao jose da coroa grande
# Processing Record 23 of Set 2 | myanaung
# Processing Record 24 of Set 2 | marawi
# Processing Record 25 of Set 2 | languyan
# Processing Record 26 of Set 2 | vestmannaeyjar
# Processing Record 27 of Set 2 | batemans bay
# Processing Record 28 of Set 2 | hasaki
# Processing Record 29 of Set 2 | russkaya polyana
# Processing Record 30 of Set 2 | qaanaaq
# Processing Record 31 of Set 2 | riacho de santana
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | carnarvon
# Processing Record 36 of Set 2 | barotac viejo
# Processing Record 37 of Set 2 | kontagora
# Processing Record 38 of Set 2 | mahebourg
# Processing Record 39 of Set 2 | blythe
# Processing Record 40 of Set 2 | albany
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | calatayud
# Processing Record 44 of Set 2 | northam
# Processing Record 45 of Set 2 | micheweni
# Processing Record 46 of Set 2 | cayenne
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | raduzhnyy
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | soderhamn
# Processing Record 2 of Set 3 | lavrentiya
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | hirtshals
# Processing Record 9 of Set 3 | katobu
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | dingle
# Processing Record 13 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 14 of Set 3 | viedma
# Processing Record 15 of Set 3 | kyra
# Processing Record 16 of Set 3 | te anau
# Processing Record 17 of Set 3 | kichera
# Processing Record 18 of Set 3 | gimli
# Processing Record 19 of Set 3 | cherskiy
# Processing Record 20 of Set 3 | bodden town
# Processing Record 21 of Set 3 | alyangula
# Processing Record 22 of Set 3 | bandarbeyla
# Processing Record 23 of Set 3 | khatanga
# Processing Record 24 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 3 | khairagarh
# Processing Record 26 of Set 3 | namatanai
# Processing Record 27 of Set 3 | vardo
# Processing Record 28 of Set 3 | voi
# Processing Record 29 of Set 3 | pascagoula
# Processing Record 30 of Set 3 | namibe
# Processing Record 31 of Set 3 | sao filipe
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | kendari
# Processing Record 34 of Set 3 | tabuk
# Processing Record 35 of Set 3 | pangai
# Processing Record 36 of Set 3 | auki
# Processing Record 37 of Set 3 | taoudenni
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | aklavik
# Processing Record 41 of Set 3 | waingapu
# Processing Record 42 of Set 3 | berlevag
# Processing Record 43 of Set 3 | luderitz
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | am timan
# Processing Record 46 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 3 | prince albert
# Processing Record 48 of Set 3 | dimbokro
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | amapa
# Processing Record 1 of Set 4 | upernavik
# Processing Record 2 of Set 4 | petatlan
# Processing Record 3 of Set 4 | hofn
# Processing Record 4 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 4 | esperance
# Processing Record 6 of Set 4 | santa marta
# Processing Record 7 of Set 4 | bathsheba
# Processing Record 8 of Set 4 | emba
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | guia de isora
# Processing Record 11 of Set 4 | taitung
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | nizhniy lomov
# Processing Record 14 of Set 4 | sterling
# Processing Record 15 of Set 4 | doha
# Processing Record 16 of Set 4 | olavarria
# Processing Record 17 of Set 4 | huntingdon
# Processing Record 18 of Set 4 | khotkovo
# Processing Record 19 of Set 4 | hilo
# Processing Record 20 of Set 4 | providencia
# Processing Record 21 of Set 4 | imeni poliny osipenko
# Processing Record 22 of Set 4 | wasilla
# Processing Record 23 of Set 4 | chekmagush
# Processing Record 24 of Set 4 | cape town
# Processing Record 25 of Set 4 | kovdor
# Processing Record 26 of Set 4 | vyartsilya
# Processing Record 27 of Set 4 | riachao das neves
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | severo-kurilsk
# Processing Record 30 of Set 4 | jumla
# Processing Record 31 of Set 4 | kasongo-lunda
# Processing Record 32 of Set 4 | nuuk
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | fortuna
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | yulara
# Processing Record 37 of Set 4 | college
# Processing Record 38 of Set 4 | kjollefjord
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | victoria
# Processing Record 41 of Set 4 | cap malheureux
# Processing Record 42 of Set 4 | vostok
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | guayaquil
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 4 | geraldton
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | kudinovo
# Processing Record 50 of Set 4 | salalah
# Processing Record 1 of Set 5 | dongsheng
# Processing Record 2 of Set 5 | bondoukou
# Processing Record 3 of Set 5 | banda aceh
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | karpogory
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | maniitsoq
# Processing Record 8 of Set 5 | bonavista
# Processing Record 9 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 10 of Set 5 | yuzhou
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | longyearbyen
# Processing Record 13 of Set 5 | quattro castella
# Processing Record 14 of Set 5 | gizo
# Processing Record 15 of Set 5 | lukaya
# Processing Record 16 of Set 5 | kinablangan
# Processing Record 17 of Set 5 | bilibino
# Processing Record 18 of Set 5 | goderich
# Processing Record 19 of Set 5 | dhanera
# Processing Record 20 of Set 5 | zemio
# Processing Record 21 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 5 | beli potok
# Processing Record 23 of Set 5 | havelock
# Processing Record 24 of Set 5 | ahipara
# Processing Record 25 of Set 5 | santa isabel do rio negro
# Processing Record 26 of Set 5 | ahlat
# Processing Record 27 of Set 5 | abramovka
# Processing Record 28 of Set 5 | pontal do parana
# Processing Record 29 of Set 5 | sitka
# Processing Record 30 of Set 5 | kati
# Processing Record 31 of Set 5 | zhigansk
# Processing Record 32 of Set 5 | huaidian
# Processing Record 33 of Set 5 | cavalcante
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 37 of Set 5 | novosheshminsk
# Processing Record 38 of Set 5 | soyo
# Processing Record 39 of Set 5 | pishin
# Processing Record 40 of Set 5 | constitucion
# Processing Record 41 of Set 5 | chokurdakh
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | port hedland
# Processing Record 45 of Set 5 | lasa
# Processing Record 46 of Set 5 | rawson
# Processing Record 47 of Set 5 | la ronge
# Processing Record 48 of Set 5 | bacolod
# Processing Record 49 of Set 5 | zharkent
# Processing Record 50 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 1 of Set 6 | danilov
# Processing Record 2 of Set 6 | medea
# Processing Record 3 of Set 6 | coihaique
# Processing Record 4 of Set 6 | altay
# Processing Record 5 of Set 6 | provideniya
# Processing Record 6 of Set 6 | zyryanovsk
# Processing Record 7 of Set 6 | kuchera
# Processing Record 8 of Set 6 | vao
# Processing Record 9 of Set 6 | porto walter
# Processing Record 10 of Set 6 | soure
# Processing Record 11 of Set 6 | kahului
# Processing Record 12 of Set 6 | shimoda
# Processing Record 13 of Set 6 | harlingen
# Processing Record 14 of Set 6 | vila velha
# Processing Record 15 of Set 6 | russell
# Processing Record 16 of Set 6 | chimbote
# Processing Record 17 of Set 6 | hovd
# Processing Record 18 of Set 6 | constantine
# Processing Record 19 of Set 6 | olafsvik
# Processing Record 20 of Set 6 | fort nelson
# Processing Record 21 of Set 6 | itupiranga
# Processing Record 22 of Set 6 | flinders
# Processing Record 23 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 6 | canton
# Processing Record 25 of Set 6 | morondava
# Processing Record 26 of Set 6 | umea
# Processing Record 27 of Set 6 | talnakh
# Processing Record 28 of Set 6 | charyshskoye
# Processing Record 29 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 6 | doicesti
# Processing Record 31 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 32 of Set 6 | sandy bay
# Processing Record 33 of Set 6 | zeya
# Processing Record 34 of Set 6 | guerrero negro
# Processing Record 35 of Set 6 | basco
# Processing Record 36 of Set 6 | sao joao da barra
# Processing Record 37 of Set 6 | requena
# Processing Record 38 of Set 6 | zelenoborsk
# Processing Record 39 of Set 6 | korbach
# Processing Record 40 of Set 6 | kavieng
# Processing Record 41 of Set 6 | puerto escondido
# Processing Record 42 of Set 6 | whitehorse
# Processing Record 43 of Set 6 | buala
# Processing Record 44 of Set 6 | minudasht
# Processing Record 45 of Set 6 | inuvik
# Processing Record 46 of Set 6 | grand baie
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | ofaqim
# Processing Record 49 of Set 6 | camabatela
# Processing Record 50 of Set 6 | leh
# Processing Record 1 of Set 7 | taree
# Processing Record 2 of Set 7 | benxi
# Processing Record 3 of Set 7 | ilulissat
# Processing Record 4 of Set 7 | taloda
# Processing Record 5 of Set 7 | wanning
# Processing Record 6 of Set 7 | monselice
# Processing Record 7 of Set 7 | kirakira
# Processing Record 8 of Set 7 | rayon
# Processing Record 9 of Set 7 | erzin
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | zhireken
# Processing Record 12 of Set 7 | valparaiso
# Processing Record 13 of Set 7 | san miguelito
# Processing Record 14 of Set 7 | parit buntar
# Processing Record 15 of Set 7 | ahuimanu
# Processing Record 16 of Set 7 | oranjestad
# Processing Record 17 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 7 | nihtaur
# Processing Record 19 of Set 7 | buguruslan
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | henties bay
# Processing Record 22 of Set 7 | adrar
# Processing Record 23 of Set 7 | jabinyanah
# Processing Record 24 of Set 7 | manoel urbano
# Processing Record 25 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 7 | portobelo
# Processing Record 27 of Set 7 | palmer
# Processing Record 28 of Set 7 | sinnamary
# Processing Record 29 of Set 7 | barcelos
# Processing Record 30 of Set 7 | arys
# Processing Record 31 of Set 7 | kudahuvadhoo
# Processing Record 32 of Set 7 | hithadhoo
# Processing Record 33 of Set 7 | boguchany
# Processing Record 34 of Set 7 | manggar
# Processing Record 35 of Set 7 | taltal
# Processing Record 36 of Set 7 | zdvinsk
# Processing Record 37 of Set 7 | saint-joseph
# Processing Record 38 of Set 7 | amli
# Processing Record 39 of Set 7 | pevek
# Processing Record 40 of Set 7 | sioux lookout
# Processing Record 41 of Set 7 | ulaangom
# Processing Record 42 of Set 7 | beringovskiy
# Processing Record 43 of Set 7 | guangyuan
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | karasburg
# Processing Record 46 of Set 7 | devils lake
# Processing Record 47 of Set 7 | kishni
# Processing Record 48 of Set 7 | eureka
# Processing Record 49 of Set 7 | ponta do sol
# Processing Record 50 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 8 | rocha
# Processing Record 2 of Set 8 | qui nhon
# Processing Record 3 of Set 8 | zhaoqing
# Processing Record 4 of Set 8 | tezu
# Processing Record 5 of Set 8 | dillon
# Processing Record 6 of Set 8 | shelburne
# Processing Record 7 of Set 8 | tabukiniberu
# City not found. Skipping...
# Processing Record 8 of Set 8 | pochinki
# Processing Record 9 of Set 8 | oriximina
# Processing Record 10 of Set 8 | kloulklubed
# Processing Record 11 of Set 8 | wucheng
# Processing Record 12 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 8 | zhezkazgan
# Processing Record 14 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 8 | livingston
# Processing Record 16 of Set 8 | tagusao
# Processing Record 17 of Set 8 | alugan
# Processing Record 18 of Set 8 | burnie
# Processing Record 19 of Set 8 | along
# Processing Record 20 of Set 8 | nanortalik
# Processing Record 21 of Set 8 | terney
# Processing Record 22 of Set 8 | nome
# Processing Record 23 of Set 8 | brae
# Processing Record 24 of Set 8 | newry
# Processing Record 25 of Set 8 | itatskiy
# Processing Record 26 of Set 8 | vakhrushev
# Processing Record 27 of Set 8 | puerto padre
# Processing Record 28 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 8 | port augusta
# Processing Record 32 of Set 8 | karratha
# Processing Record 33 of Set 8 | moba
# Processing Record 34 of Set 8 | santa maria do suacui
# Processing Record 35 of Set 8 | springbok
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | quatre cocos
# Processing Record 38 of Set 8 | quchan
# Processing Record 39 of Set 8 | mokhsogollokh
# Processing Record 40 of Set 8 | salgueiro
# Processing Record 41 of Set 8 | isiro
# Processing Record 42 of Set 8 | xanxere
# Processing Record 43 of Set 8 | port blair
# Processing Record 44 of Set 8 | kuytun
# Processing Record 45 of Set 8 | uinskoye
# Processing Record 46 of Set 8 | mkushi
# Processing Record 47 of Set 8 | samarai
# Processing Record 48 of Set 8 | porto santo
# Processing Record 49 of Set 8 | burica
# City not found. Skipping...
# Processing Record 50 of Set 8 | zhangye
# Processing Record 1 of Set 9 | progreso
# Processing Record 2 of Set 9 | ciudad bolivar
# Processing Record 3 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 9 | puri
# Processing Record 5 of Set 9 | sao miguel do araguaia
# Processing Record 6 of Set 9 | loiza
# Processing Record 7 of Set 9 | fort frances
# Processing Record 8 of Set 9 | tuckahoe
# Processing Record 9 of Set 9 | flagstaff
# Processing Record 10 of Set 9 | marzuq
# Processing Record 11 of Set 9 | vallenar
# Processing Record 12 of Set 9 | bangkok
# Processing Record 13 of Set 9 | san patricio
# Processing Record 14 of Set 9 | batangafo
# Processing Record 15 of Set 9 | veraval
# Processing Record 16 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | townsville
# Processing Record 18 of Set 9 | boa vista
# Processing Record 19 of Set 9 | comrat
# Processing Record 20 of Set 9 | harper
# Processing Record 21 of Set 9 | lucea
# Processing Record 22 of Set 9 | sharjah
# Processing Record 23 of Set 9 | mwene-ditu
# Processing Record 24 of Set 9 | caravelas
# Processing Record 25 of Set 9 | port elizabeth
# Processing Record 26 of Set 9 | walvis bay
# Processing Record 27 of Set 9 | asaba
# Processing Record 28 of Set 9 | sungaipenuh
# Processing Record 29 of Set 9 | onverwacht
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | omsukchan
# Processing Record 32 of Set 9 | sibolga
# Processing Record 33 of Set 9 | ambilobe
# Processing Record 34 of Set 9 | tahe
# Processing Record 35 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | potrero del llano
# Processing Record 38 of Set 9 | encruzilhada
# Processing Record 39 of Set 9 | manzanillo
# Processing Record 40 of Set 9 | trincomalee
# Processing Record 41 of Set 9 | honningsvag
# Processing Record 42 of Set 9 | tevaitoa
# Processing Record 43 of Set 9 | la plata
# Processing Record 44 of Set 9 | hambantota
# Processing Record 45 of Set 9 | kostyantynivka
# Processing Record 46 of Set 9 | zhucheng
# Processing Record 47 of Set 9 | birao
# Processing Record 48 of Set 9 | adet
# Processing Record 49 of Set 9 | morro bay
# Processing Record 50 of Set 9 | arman
# Processing Record 1 of Set 10 | emerald
# Processing Record 2 of Set 10 | tautira
# Processing Record 3 of Set 10 | port hardy
# Processing Record 4 of Set 10 | takoradi
# Processing Record 5 of Set 10 | cam ranh
# Processing Record 6 of Set 10 | lerik
# Processing Record 7 of Set 10 | nagato
# Processing Record 8 of Set 10 | neftegorsk
# Processing Record 9 of Set 10 | san cristobal
# Processing Record 10 of Set 10 | antigonish
# Processing Record 11 of Set 10 | sunrise manor
# Processing Record 12 of Set 10 | dunedin
# Processing Record 13 of Set 10 | rio grande
# Processing Record 14 of Set 10 | ponta delgada
# Processing Record 15 of Set 10 | gurupi
# Processing Record 16 of Set 10 | ngudu
# Processing Record 17 of Set 10 | coquimbo
# Processing Record 18 of Set 10 | oksfjord
# Processing Record 19 of Set 10 | jambi
# Processing Record 20 of Set 10 | peterhead
# Processing Record 21 of Set 10 | vaitape
# Processing Record 22 of Set 10 | alanya
# Processing Record 23 of Set 10 | norman wells
# Processing Record 24 of Set 10 | sangar
# Processing Record 25 of Set 10 | bara
# Processing Record 26 of Set 10 | mount airy
# Processing Record 27 of Set 10 | yuzhnouralsk
# Processing Record 28 of Set 10 | isangel
# Processing Record 29 of Set 10 | kachikau
# City not found. Skipping...
# Processing Record 30 of Set 10 | alice springs
# Processing Record 31 of Set 10 | vila franca do campo
# Processing Record 32 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 10 | yar-sale
# Processing Record 34 of Set 10 | celestun
# Processing Record 35 of Set 10 | viransehir
# Processing Record 36 of Set 10 | codrington
# Processing Record 37 of Set 10 | liverpool
# Processing Record 38 of Set 10 | qena
# Processing Record 39 of Set 10 | lorengau
# Processing Record 40 of Set 10 | nambucca heads
# Processing Record 41 of Set 10 | ibra
# Processing Record 42 of Set 10 | kalmunai
# Processing Record 43 of Set 10 | deori khas
# Processing Record 44 of Set 10 | kayerkan
# Processing Record 45 of Set 10 | jalu
# Processing Record 46 of Set 10 | hervey bay
# Processing Record 47 of Set 10 | ornskoldsvik
# Processing Record 48 of Set 10 | legnago
# Processing Record 49 of Set 10 | aden
# Processing Record 50 of Set 10 | kamaishi
# Processing Record 1 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 11 | marysville
# Processing Record 3 of Set 11 | semnan
# Processing Record 4 of Set 11 | palana
# Processing Record 5 of Set 11 | arlit
# Processing Record 6 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 7 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 11 | terrasini
# Processing Record 9 of Set 11 | zalesovo
# Processing Record 10 of Set 11 | atasu
# Processing Record 11 of Set 11 | nicoya
# Processing Record 12 of Set 11 | aripuana
# Processing Record 13 of Set 11 | ewa beach
# Processing Record 14 of Set 11 | sorland
# Processing Record 15 of Set 11 | dong xoai
# Processing Record 16 of Set 11 | gomoh
# Processing Record 17 of Set 11 | gat
# Processing Record 18 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 11 | vondrozo
# Processing Record 20 of Set 11 | antanifotsy
# Processing Record 21 of Set 11 | torres
# Processing Record 22 of Set 11 | high level
# Processing Record 23 of Set 11 | tilichiki
# Processing Record 24 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 11 | issoire
# Processing Record 26 of Set 11 | moussoro
# Processing Record 27 of Set 11 | anloga
# Processing Record 28 of Set 11 | praya
# Processing Record 29 of Set 11 | san vicente
# Processing Record 30 of Set 11 | alexandria
# Processing Record 31 of Set 11 | cururupu
# Processing Record 32 of Set 11 | saint-francois
# Processing Record 33 of Set 11 | opuwo
# Processing Record 34 of Set 11 | draguignan
# Processing Record 35 of Set 11 | bekhtery
# Processing Record 36 of Set 11 | immokalee
# Processing Record 37 of Set 11 | solginskiy
# Processing Record 38 of Set 11 | nha trang
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | moranbah
# Processing Record 41 of Set 11 | ilabaya
# Processing Record 42 of Set 11 | bairiki
# Processing Record 43 of Set 11 | hirara
# Processing Record 44 of Set 11 | malpe
# Processing Record 45 of Set 11 | haines junction
# Processing Record 46 of Set 11 | gondal
# Processing Record 47 of Set 11 | cartagena
# Processing Record 48 of Set 11 | evinayong
# Processing Record 49 of Set 11 | kabinda
# Processing Record 50 of Set 11 | derzhavinsk
# Processing Record 1 of Set 12 | ozernovskiy
# Processing Record 2 of Set 12 | kozhevnikovo
# Processing Record 3 of Set 12 | teguldet
# Processing Record 4 of Set 12 | cabedelo
# Processing Record 5 of Set 12 | egvekinot
# Processing Record 6 of Set 12 | rodrigues alves
# Processing Record 7 of Set 12 | tsienyane
# City not found. Skipping...
# Processing Record 8 of Set 12 | tura
# Processing Record 9 of Set 12 | tabou
# Processing Record 10 of Set 12 | mindelo
# Processing Record 11 of Set 12 | morros
# Processing Record 12 of Set 12 | tiksi
# Processing Record 13 of Set 12 | joshimath
# Processing Record 14 of Set 12 | richards bay
# Processing Record 15 of Set 12 | ambovombe
# Processing Record 16 of Set 12 | sturgeon bay
# Processing Record 17 of Set 12 | ilebo
# Processing Record 18 of Set 12 | cavarzere
# Processing Record 19 of Set 12 | marsh harbour
# Processing Record 20 of Set 12 | raudeberg
# Processing Record 21 of Set 12 | jatibonico
# Processing Record 22 of Set 12 | laguna
# Processing Record 23 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 24 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 25 of Set 12 | lodja
# Processing Record 26 of Set 12 | togul
# Processing Record 27 of Set 12 | magadan
# Processing Record 28 of Set 12 | kroya
# Processing Record 29 of Set 12 | poum
# Processing Record 30 of Set 12 | pedernales
# Processing Record 31 of Set 12 | saint anthony
# Processing Record 32 of Set 12 | sjenica
# Processing Record 33 of Set 12 | mackenzie
# Processing Record 34 of Set 12 | vicuna
# Processing Record 35 of Set 12 | san angelo
# Processing Record 36 of Set 12 | santa rosa
# Processing Record 37 of Set 12 | koson
# Processing Record 38 of Set 12 | matiri
# Processing Record 39 of Set 12 | jackson
# Processing Record 40 of Set 12 | bonthe
# Processing Record 41 of Set 12 | bida
# Processing Record 42 of Set 12 | alberton
# Processing Record 43 of Set 12 | malakisi
# City not found. Skipping...
# Processing Record 44 of Set 12 | douglas
# Processing Record 45 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 46 of Set 12 | balad
# Processing Record 47 of Set 12 | calama
# Processing Record 48 of Set 12 | byron bay
# Processing Record 49 of Set 12 | chudniv
# Processing Record 50 of Set 12 | serebryansk
# Processing Record 1 of Set 13 | atherton
# Processing Record 2 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 13 | kayes
# Processing Record 4 of Set 13 | bath
# Processing Record 5 of Set 13 | praia
# Processing Record 6 of Set 13 | tateyama
# Processing Record 7 of Set 13 | mbigou
# Processing Record 8 of Set 13 | uporovo
# Processing Record 9 of Set 13 | moree
# Processing Record 10 of Set 13 | maralal
# Processing Record 11 of Set 13 | vetlanda
# Processing Record 12 of Set 13 | hamilton
# Processing Record 13 of Set 13 | fare
# Processing Record 14 of Set 13 | da nang
# Processing Record 15 of Set 13 | punta alta
# Processing Record 16 of Set 13 | carutapera
# Processing Record 17 of Set 13 | bealanana
# Processing Record 18 of Set 13 | tuxtepec
# Processing Record 19 of Set 13 | hvolsvollur
# Processing Record 20 of Set 13 | baghdad
# Processing Record 21 of Set 13 | lawar
# City not found. Skipping...
# Processing Record 22 of Set 13 | twin falls
# Processing Record 23 of Set 13 | lethem
# Processing Record 24 of Set 13 | popondetta
# Processing Record 25 of Set 13 | kamenka
# Processing Record 26 of Set 13 | batticaloa
# Processing Record 27 of Set 13 | verkhnevilyuysk
# Processing Record 28 of Set 13 | soe
# Processing Record 29 of Set 13 | kuching
# Processing Record 30 of Set 13 | camacha
# Processing Record 31 of Set 13 | tiznit
# Processing Record 32 of Set 13 | corner brook
# Processing Record 33 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | panzhihua
# Processing Record 35 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 13 | alto araguaia
# Processing Record 37 of Set 13 | uren
# Processing Record 38 of Set 13 | tarakan
# Processing Record 39 of Set 13 | wick
# Processing Record 40 of Set 13 | lazaro cardenas
# Processing Record 41 of Set 13 | dali
# Processing Record 42 of Set 13 | sovetskiy
# Processing Record 43 of Set 13 | ketchikan
# Processing Record 44 of Set 13 | chakwal
# Processing Record 45 of Set 13 | pangkalanbuun
# Processing Record 46 of Set 13 | mpika
# Processing Record 47 of Set 13 | jiuquan
# Processing Record 48 of Set 13 | lhokseumawe
# Processing Record 49 of Set 13 | alenquer
# Processing Record 50 of Set 13 | vigrestad
# Processing Record 1 of Set 14 | makakilo city
# Processing Record 2 of Set 14 | nemuro
# Processing Record 3 of Set 14 | kolbermoor
# Processing Record 4 of Set 14 | nijar
# Processing Record 5 of Set 14 | dinguiraye
# Processing Record 6 of Set 14 | blagoyevo
# Processing Record 7 of Set 14 | do rud
# City not found. Skipping...
# Processing Record 8 of Set 14 | jiaonan
# Processing Record 9 of Set 14 | sam roi yot
# Processing Record 10 of Set 14 | tadine
# Processing Record 11 of Set 14 | dauriya
# Processing Record 12 of Set 14 | maroantsetra
# Processing Record 13 of Set 14 | myatlevo
# Processing Record 14 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 15 of Set 14 | marsa matruh
# Processing Record 16 of Set 14 | aksha
# Processing Record 17 of Set 14 | saldanha
# Processing Record 18 of Set 14 | sal rei
# Processing Record 19 of Set 14 | nanchang
# Processing Record 20 of Set 14 | bolotnoye
# Processing Record 21 of Set 14 | estelle
# Processing Record 22 of Set 14 | amudat
# Processing Record 23 of Set 14 | lamballe
# Processing Record 24 of Set 14 | asyut
# Processing Record 25 of Set 14 | belle fourche
# Processing Record 26 of Set 14 | bahia blanca
# Processing Record 27 of Set 14 | maracas
# Processing Record 28 of Set 14 | den chai
# Processing Record 29 of Set 14 | erenhot
# Processing Record 30 of Set 14 | ancud
# Processing Record 31 of Set 14 | champerico
# Processing Record 32 of Set 14 | invermere
# Processing Record 33 of Set 14 | clyde river
# Processing Record 34 of Set 14 | chara
# Processing Record 35 of Set 14 | kibre mengist
# Processing Record 36 of Set 14 | lufilufi
# Processing Record 37 of Set 14 | anadyr
# Processing Record 38 of Set 14 | lieksa
# Processing Record 39 of Set 14 | oyama
# Processing Record 40 of Set 14 | pocatello
# Processing Record 41 of Set 14 | puerto del rosario
# Processing Record 42 of Set 14 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 44 of Set 14 | urengoy
# Processing Record 45 of Set 14 | kwakoa
# Processing Record 46 of Set 14 | phan thiet
# Processing Record 47 of Set 14 | sao raimundo nonato
# Processing Record 48 of Set 14 | mount gambier
# Processing Record 49 of Set 14 | merauke
# Processing Record 50 of Set 14 | wazzan
# City not found. Skipping...
# Processing Record 1 of Set 15 | mandalgovi
# Processing Record 2 of Set 15 | parfino
# Processing Record 3 of Set 15 | yantai
# Processing Record 4 of Set 15 | sehithwa
# Processing Record 5 of Set 15 | urucara
# Processing Record 6 of Set 15 | tiarei
# Processing Record 7 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 15 | basqal
# Processing Record 9 of Set 15 | ishigaki
# Processing Record 10 of Set 15 | malindi
# Processing Record 11 of Set 15 | hobyo
# Processing Record 12 of Set 15 | lukulu
# Processing Record 13 of Set 15 | paisley
# Processing Record 14 of Set 15 | rumford
# Processing Record 15 of Set 15 | pandan
# Processing Record 16 of Set 15 | salym
# Processing Record 17 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 15 | oksbol
# Processing Record 19 of Set 15 | pimenta bueno
# Processing Record 20 of Set 15 | port-gentil
# Processing Record 21 of Set 15 | wau
# Processing Record 22 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 23 of Set 15 | shingu
# Processing Record 24 of Set 15 | dunmore town
# Processing Record 25 of Set 15 | kualakapuas
# Processing Record 26 of Set 15 | carpinteria
# Processing Record 27 of Set 15 | rupert
# Processing Record 28 of Set 15 | lubango
# Processing Record 29 of Set 15 | muros
# Processing Record 30 of Set 15 | lagoa
# Processing Record 31 of Set 15 | kardla
# Processing Record 32 of Set 15 | fukue
# Processing Record 33 of Set 15 | paso de carrasco
# Processing Record 34 of Set 15 | inhambane
# Processing Record 35 of Set 15 | bure
# Processing Record 36 of Set 15 | bemidji
# Processing Record 37 of Set 15 | matara
# Processing Record 38 of Set 15 | padang
# Processing Record 39 of Set 15 | sola
# Processing Record 40 of Set 15 | beloha
# Processing Record 41 of Set 15 | shush
# Processing Record 42 of Set 15 | thinadhoo
# Processing Record 43 of Set 15 | nyrob
# Processing Record 44 of Set 15 | tvoroyri
# Processing Record 45 of Set 15 | faya
# Processing Record 46 of Set 15 | husavik
# Processing Record 47 of Set 15 | sorong
# Processing Record 48 of Set 15 | kununurra
# Processing Record 49 of Set 15 | stratford
# Processing Record 50 of Set 15 | peniche
# Processing Record 1 of Set 16 | iquitos
# Processing Record 2 of Set 16 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 16 | zhaotong
# Processing Record 4 of Set 16 | buchanan
# Processing Record 5 of Set 16 | gore
# Processing Record 6 of Set 16 | flin flon
# Processing Record 7 of Set 16 | quzhou
# Processing Record 8 of Set 16 | penzance
# Processing Record 9 of Set 16 | abha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     East London      ZA -33.0153   27.9116     69.69        89          96
# 1       Hermiston      US  45.8404 -119.2895     52.45        61          35
# 2          Aykhal      RU  66.0000  111.5000     -9.42        99          99
# 3      Isla Vista      US  34.4133 -119.8610     68.31        45           0
# 4    Punta Arenas      CL -53.1500  -70.9167     55.51        62          40
# 5        Katsuura      JP  35.1333  140.3000     41.14        33          21
# 6  Cabo San Lucas      MX  22.8909 -109.9124     68.31        63           0
# 7         Ternate      ID   0.8000  127.4000     82.56        76         100
# 8            Naze      JP  28.3667  129.4833     54.52        66          99
# 9         Quesnel      CA  52.9999 -122.5029     34.30        93         100
#
#    Wind Speed Current Description
# 0       15.93          light rain
# 1        3.44    scattered clouds
# 2        3.33     overcast clouds
# 3        4.61           clear sky
# 4        9.22    scattered clouds
# 5        9.71          few clouds
# 6        5.75           clear sky
# 7        9.71     overcast clouds
# 8       14.67     overcast clouds
# 9        3.44     overcast clouds

# %%
output_data_file = "Weather_Database-WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
